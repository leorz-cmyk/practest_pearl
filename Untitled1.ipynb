# %% [markdown]
# <a href="https://colab.research.google.com/github/leorz-cmyk/practest_pearl/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
score = input("Enter how many scores you will input: ")
score = int(score)

#input scores
num1 = int(input("Enter your first score: "))
num2 = int(input("Enter your second score: "))

def average(num1, num2):
  return (num1 + num2) / 2

avg_score = average(num1, num2)
print(avg_score)

#compare the numbers
if avg_score > 60:
  print("PASSED")
elif avg_score < 60:
  print("FAILED")
# Out:
# Enter your name: h
# Enter how many scores you will input: 2
# Enter your first score: 93
# Enter your second score: 52
# 72.5
# PASSED
